# %%
import kagglehub
from rich.jupyter import display

# Download latest version
path = kagglehub.dataset_download("harrynicolasjr/literary-magazine-descriptions")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 18.0k/18.0k [00:00<00:00, 5.20MB/s]
# Extracting files...
# Path to dataset files: C:\Users\juniu\.cache\kagglehub\datasets\harrynicolasjr\literary-magazine-descriptions\versions\5

# %%
import pandas as pd

# %%
mags = pd.read_csv("C:/Users/juniu/Documents/lit_Mags.csv", encoding="ISO-8859-1")
mags.to_csv("final_mags.csv", index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = plt.axes()
sns.heatmap(mags.isna().transpose(), cbar=False, ax=ax)

plt.xlabel("Columns")
plt.ylabel("Missing values")

plt.show()

# %%
import pandas as pd
# Step 1: Load the original CSV file into a DataFrame
mags = pd.read_csv(f"{path}/cleaned_lit_mag_open_markets (1).csv")

# Step 2: Filter out rows with missing 'genres'
mags_missing = mags[~mags["genres"].isna()].copy()

# Step 3: Save the filtered DataFrame to a new CSV file
mags_missing.to_csv("cleaned_Mags.csv", index=False)
