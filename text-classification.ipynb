# %%
import pandas as pd

mags = pd.read_csv("cleaned_Mags.csv")

# %%
# Load your CSV
df = pd.read_csv("cleaned_Mags.csv")

# Combine two columns into a new one
df["genres"] = df["lengths"] + " " + df["genres"]

# Save it (optional)
df.to_csv("cleaned_Mags.csv", index=False)

# Display it
print(df.head())
# Out:
#                         market_name  \
# 0  Halfway Down the Stairs - Poetry
# 1                          Harper's
# 2        Harvey Duckman Presents...
# 3     Haven Spec Magazine - Fiction
# 4      Haven Spec Magazine - Poetry
#
#                                               genres  \
# 0             Poetry Poetry Poetry General, Literary
# 1  Flash, Short Story, Novelette, Novella Flash, ...
# 2  Short Story, Flash Short Story, Flash Short St...
# 3  Flash, Short Story Flash, Short Story Flash, S...
# 4  Poetry Poetry Poetry Fantasy, Horror, Science ...
#
#                                   lengths response_time  \
# 0                                  Poetry        8 days
# 1  Flash, Short Story, Novelette, Novella       26 days
# 2                      Short Story, Flash      100 days
# 3                      Flash, Short Story       51 days
# 4                                  Poetry       65 days
#
#                                          description  row_number  \
# ...

# %%
mags["genres"].value_counts().reset_index()
# Out:
#                                                genres  count
# 0                                             General    207
# 1                                   General, Literary     57
# 2                    Fantasy, Horror, Science Fiction     25
# 3                                            Literary     11
# 4                   General, Fantasy, Science Fiction      9
# ..                                                ...    ...
# 75  Young Adult, Literary, General, Fantasy, Scien...      1
# 76  Fantasy, Mystery/Crime, Science Fiction, Histo...      1
# 77  Action/Adventure, Horror, Mystery/Crime, Suspe...      1
# 78  Fantasy, Horror, Mystery/Crime, Science Fictio...      1
# 79                              Horror, Mystery/Crime      1
#
# [80 rows x 2 columns]
